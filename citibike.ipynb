# %%
import pandas as pd
import glob
import os

# %%
oct_to_load = os.path.join('resources/JC-202210-citibike-tripdata.csv')
nov_to_load = os.path.join('resources/JC-202211-citibike-tripdata.csv')
dec_to_load = os.path.join('resources/JC-202212-citibike-tripdata.csv')

october_2022 = pd.read_csv(oct_to_load)
november_2022 = pd.read_csv(nov_to_load)
december_2022 = pd.read_csv(dec_to_load)

october_2022.tail()
# Out:
#                 ride_id  rideable_type           started_at  \
# 89553  29D7126C0D802E5B  electric_bike  2022-10-08 07:38:41
# 89554  D50B41C904A7C5B3  electric_bike  2022-10-27 08:56:15
# 89555  B4240A4EEB9DB4D5   classic_bike  2022-10-23 08:28:34
# 89556  5F76013D50A68AA7   classic_bike  2022-10-12 12:19:26
# 89557  D47114548D40A009   classic_bike  2022-10-14 08:46:52
#
#                   ended_at     start_station_name start_station_id  \
# 89553  2022-10-08 07:44:43  Bloomfield St & 15 St            HB203
# 89554  2022-10-27 09:02:04  Bloomfield St & 15 St            HB203
# 89555  2022-10-23 08:34:12  Bloomfield St & 15 St            HB203
# 89556  2022-10-12 12:26:01  Bloomfield St & 15 St            HB203
# 89557  2022-10-14 08:52:54  Bloomfield St & 15 St            HB203
#
#        end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 89553  7 St & Monroe St          HB304  40.754530 -74.026580  40.746413
# ...

# %%
complete = pd.concat([october_2022, november_2022, december_2022])
complete.tail()
# Out:
#                 ride_id  rideable_type           started_at  \
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 48580  2022-12-06 15:53:57                                  Dey St
# 48581  2022-12-08 08:23:33           9 St HBLR - Jackson St & 8 St
# 48582  2022-12-23 14:14:18  Mama Johnson Field - 4 St & Jackson St
# 48583  2022-12-02 04:46:55  Mama Johnson Field - 4 St & Jackson St
# 48584  2022-12-30 14:55:37       14 St Ferry - 14 St & Shipyard Ln
#
#       start_station_id                  end_station_name end_station_id  \
# 48580            JC065                    Riverview Park          JC057
# ...

# %%
complete.dropna(axis='rows', how='any')
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      705B9BE3434233E7   classic_bike  2022-10-27 11:20:23
# 1      660EE8D1E1D21D0F   classic_bike  2022-10-23 22:56:06
# 2      81CCDC472990FD62  electric_bike  2022-10-30 17:47:15
# 3      155ABDCC56D1E9D3   classic_bike  2022-10-11 17:28:53
# 4      47DB1136D49EDA96   classic_bike  2022-10-16 22:22:34
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-10-27 11:55:47                           Grove St PATH
# 1      2022-10-23 23:09:03                           Grove St PATH
# ...

# %%
complete.to_csv('resources/oct_nov_dec_2022_2.csv', index=False)
